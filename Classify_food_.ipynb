# %%
# !pip install ibm-watson

# %%
import json
from ibm_watson import VisualRecognitionV3
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator

authenticator = IAMAuthenticator('n-O3lnar4FzKvyoRh_HwgHNd4LL9qo3NwkjFRYyuAVzB')
visual_recognition = VisualRecognitionV3(
    version='2018-03-19',
    authenticator=authenticator
)

visual_recognition.set_service_url('https://api.us-south.visual-recognition.watson.cloud.ibm.com/instances/0122df37-a714-4962-a6f2-2836f1e41ced')

url = 'https://ibm.biz/Bd2NPs'
classifier_ids = ["food"]

classes_result = visual_recognition.classify(url=url, classifier_ids=classifier_ids).get_result()
print(json.dumps(classes_result, indent=2))
# Out:
# {
#   "images": [
#     {
#       "classifiers": [
#         {
#           "classifier_id": "food",
#           "name": "food",
#           "classes": [
#             {
#               "class": "apple",
#               "score": 0.572,
#               "type_hierarchy": "/fruit/accessory fruit/apple"
#             },
#             {
#               "class": "accessory fruit",
#               "score": 0.572
#             },
#             {
#               "class": "fruit",
#               "score": 0.805
#             },
#             {
#               "class": "banana",
#               "score": 0.5,
#               "type_hierarchy": "/fruit/banana"
#             }
#           ]
#         }
#       ],
#       "source_url": "https://ibm.biz/Bd2NPs",
#       "resolved_url": "https://watson-developer-cloud.github.io/doc-tutorial-downloads/visual-recognition/fruitbowl.jpg"
#     }
#   ],
#   "images_processed": 1,
#   "custom_classes": 0
# }
